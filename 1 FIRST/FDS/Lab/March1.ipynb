# %%
import sklearn
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df=pd.read_csv("titanic dataset.csv")
titanic_df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
#Drop the column which do not contribute to our problem

titanic_df.drop(['PassengerId','Name','Ticket','Cabin'],axis='columns',inplace=True)
titanic_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
#check the null rows by row

titanic_df[titanic_df.isnull().any(axis=1)].count()
# Out:
# Survived    179
# Pclass      179
# Sex         179
# Age           2
# SibSp       179
# Parch       179
# Fare        179
# Embarked    177
# dtype: int64

# %%
#Drop rows with null value
titanic_df=titanic_df.dropna()

# %%
#Successfully deleted row with null value.
titanic_df[titanic_df.isnull().any(axis=1)].count()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
#Get the numerical description of each features
titanic_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %%
#Visual Exploration to find the survived Age
fig, ax=plt.subplots(figsize=(12,8))        #Size of figure

plt.scatter(titanic_df['Age'],titanic_df['Survived'])                      #X-axis=Age,Yaxis=Survived

plt.xlabel('Age')
plt.ylabel('Survived')
# Out:
# Text(0, 0.5, 'Survived')

# %% [markdown]
# Interpretation: Age is not directly responsible for survival

# %%
#Pivot the survived one based on gender
pd.crosstab(titanic_df['Sex'],titanic_df['Survived'])   #
# Out:
# Survived    0    1
# Sex
# female     64  195
# male      360   93

# %%
pd.crosstab(titanic_df['Pclass'],titanic_df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          64  120
# 2          90   83
# 3         270   85

# %%
# Check the correlation 
titanic_data_cor=titanic_df.corr()
titanic_data_cor
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Check the correlation
# ----> 2 titanic_data_cor=titanic_df.corr()
#       3 titanic_data_cor
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %%
from sklearn import preprocessing
